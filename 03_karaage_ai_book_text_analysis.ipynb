# %% [markdown]
# <a href="https://colab.research.google.com/github/MikiHiroshi/GoogleColabTips/blob/main/03_karaage_ai_book_text_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # テキスト分析
#
# テキスト分析のノートブックです。

# %% [markdown]
# ## データの前処理
# AIに学習させるための下準備として、学習させるデータに対して、以下の処理を順に実施します。
#
# 1. 教師データのダウンロード
# 1. 教師データのテキストを分かち書きする
# 1. 不要なデータを削除する
#
# ただ、3の不要なデータの削除は、現段階では分からないので一旦データを可視化してから再度実施することにします。

# %% [markdown]
# ### 教師データのダウンロード
#
# 青空文庫のテキストデータをGitHubからダウンロードします。

# %% [markdown]
# **ダウンロードするファイルを、夏目漱石　坊っちゃんに変更します。**

# %%
# !wget https://github.com/aozorabunko/aozorabunko/raw/master/cards/000096/files/2093_ruby_28087.zip
# !unzip 2093_ruby_28087.zip
# Out:
# --2021-06-01 13:35:20--  https://github.com/aozorabunko/aozorabunko/raw/master/cards/000096/files/2093_ruby_28087.zip
# Resolving github.com (github.com)... 140.82.112.3
# Connecting to github.com (github.com)|140.82.112.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/aozorabunko/aozorabunko/master/cards/000096/files/2093_ruby_28087.zip [following]
# --2021-06-01 13:35:21--  https://raw.githubusercontent.com/aozorabunko/aozorabunko/master/cards/000096/files/2093_ruby_28087.zip
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 421747 (412K) [application/zip]
# Saving to: ‘2093_ruby_28087.zip.1’
#
# 2093_ruby_28087.zip 100%[===================>] 411.86K  --.-KB/s    in 0.03s
#
# 2021-06-01 13:35:21 (13.6 MB/s) - ‘2093_ruby_28087.zip.1’ saved [421747/421747]
#
# Archive:  2093_ruby_28087.zip
# Made with MacWinZipper™
# replace dogura_magura.txt? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: dogura_magura.txt

# %% [markdown]
# 文字コードを nkf で調べます。最初にnkfをインストールします。

# %%
# !apt install nkf
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following package was automatically installed and is no longer required:
#   libnvidia-common-460
# Use 'apt autoremove' to remove it.
# The following NEW packages will be installed:
#   nkf
# 0 upgraded, 1 newly installed, 0 to remove and 34 not upgraded.
# Need to get 128 kB of archives.
# After this operation, 309 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/universe amd64 nkf amd64 1:2.1.4-1ubuntu2 [128 kB]
# Fetched 128 kB in 1s (164 kB/s)
# Selecting previously unselected package nkf.
# (Reading database ... 160706 files and directories currently installed.)
# Preparing to unpack .../nkf_1%3a2.1.4-1ubuntu2_amd64.deb ...
# Unpacking nkf (1:2.1.4-1ubuntu2) ...
# Setting up nkf (1:2.1.4-1ubuntu2) ...
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...

# %% [markdown]
# 文字コードを調べます。

# %%
# !nkf --guess dogura_magura.txt
# Out:
# Shift_JIS (CRLF)

# %% [markdown]
# 文字コードに対応して、ファイルを読み込みます。

# %%
text_list = []
with open('dogura_magura.txt', encoding='shift_jis') as f:
  text_list = f.readlines()

# %% [markdown]
# 読み込めたか、冒頭のテキストを確認します。

# %%
text_list[0:10]
# Out:
# ['ドグラ・マグラ\n',
#  '夢野久作\n',
#  '\n',
#  '-------------------------------------------------------\n',
#  '【テキスト中に現れる記号について】\n',
#  '\n',
#  '《》：ルビ\n',
#  '（例）蜜蜂《みつばち》\n',
#  '\n',
#  '｜：ルビの付く文字列の始まりを特定する記号\n']

# %% [markdown]
# ### データの前処理

# %% [markdown]
# 形態素解析ライブラリの「janome」をインストール

# %%
# !pip install janome
# Out:
# Collecting janome
#   Downloading https://files.pythonhosted.org/packages/a8/63/98858cbead27df7536c7e300c169da0999e9704d02220dc6700b804eeff0/Janome-0.4.1-py2.py3-none-any.whl (19.7MB)
#      |████████████████████████████████| 19.7MB 1.2MB/s
# Installing collected packages: janome
# Successfully installed janome-0.4.1

# %% [markdown]
# サンプルの文章を形態素解析して、分かち書き

# %%
from janome.tokenizer import Tokenizer

t = Tokenizer()
tokens = t.tokenize("私はからあげが好きです")

words = []
for token in tokens:
  print(token)
  words.append(token.surface)

text = ' '.join(words)
print(text)
# Out:
# 私	名詞,代名詞,一般,*,*,*,私,ワタシ,ワタシ
# は	助詞,係助詞,*,*,*,*,は,ハ,ワ
# から	助詞,格助詞,一般,*,*,*,から,カラ,カラ
# あげ	動詞,自立,*,*,一段,連用形,あげる,アゲ,アゲ
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# 好き	名詞,形容動詞語幹,*,*,*,*,好き,スキ,スキ
# です	助動詞,*,*,*,特殊・デス,基本形,です,デス,デス
# 私 は から あげ が 好き です

# %%
from janome.tokenizer import Tokenizer

t = Tokenizer()
words = []
for text in text_list:
  tokens = t.tokenize(text)
  for token in tokens:
    pos = token.part_of_speech.split(',')[0]
    if pos == '名詞':
      words.append(token.surface)

text = ' '.join(words)

# %% [markdown]
# 中身を確認

# %%
print(text[500:600])
# Out:
#  余韻 そこ ら 中 ヒッソリ 私 眼 白 ペンキ 塗 天井 裏 薄 塵埃 ほこり 蔽 裸 電球 タッタ 一つ ブラ 赤 硝子 球 ガラス だま 横腹 蠅 はえ 一 匹 よう 凝然 真下 人造 石 床

# %%
filename='wakachi_text.txt'
with open(filename, 'w', encoding='utf-8') as f:
    f.write(text)
print("file is saved")
# Out:
# file is saved

# %%
from google.colab import files
files.download(filename)

# %% [markdown]
# ## WordCloudで可視化

# %%
# !apt -y install fonts-ipafont-gothic
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following package was automatically installed and is no longer required:
#   libnvidia-common-460
# Use 'apt autoremove' to remove it.
# The following additional packages will be installed:
#   fonts-ipafont-mincho
# The following NEW packages will be installed:
#   fonts-ipafont-gothic fonts-ipafont-mincho
# 0 upgraded, 2 newly installed, 0 to remove and 34 not upgraded.
# Need to get 8,251 kB of archives.
# After this operation, 28.7 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/universe amd64 fonts-ipafont-gothic all 00303-18ubuntu1 [3,526 kB]
# Get:2 http://archive.ubuntu.com/ubuntu bionic/universe amd64 fonts-ipafont-mincho all 00303-18ubuntu1 [4,725 kB]
# Fetched 8,251 kB in 2s (4,520 kB/s)
# Selecting previously unselected package fonts-ipafont-gothic.
# (Reading database ... 160714 files and directories currently installed.)
# Preparing to unpack .../fonts-ipafont-gothic_00303-18ubuntu1_all.deb ...
# Unpacking fonts-ipafont-gothic (00303-18ubuntu1) ...
# Selecting previously unselected package fonts-ipafont-mincho.
# Preparing to unpack .../fonts-ipafont-mincho_00303-18ubuntu1_all.deb ...
# Unpacking fonts-ipafont-mincho (00303-18ubuntu1) ...
# Setting up fonts-ipafont-gothic (00303-18ubuntu1) ...
# update-alternatives: using /usr/share/fonts/opentype/ipafont-gothic/ipag.ttf to provide /usr/share/fonts/truetype/fonts-japanese-gothic.ttf (fonts-japanese-gothic.ttf) in auto mode
# Setting up fonts-ipafont-mincho (00303-18ubuntu1) ...
# update-alternatives: using /usr/share/fonts/opentype/ipafont-mincho/ipam.ttf to provide /usr/share/fonts/truetype/fonts-japanese-mincho.ttf (fonts-japanese-mincho.ttf) in auto mode
# Processing triggers for fontconfig (2.12.6-0ubuntu2) ...

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# %%
fpath = '/usr/share/fonts/opentype/ipafont-gothic/ipagp.ttf'
wordcloud = WordCloud(background_color="white", font_path=fpath, width=900, height=500).generate(text)
plt.figure(figsize=(15,12))
plt.imshow(wordcloud)
plt.axis("off")
plt.show()

# %% [markdown]
# ## データの前処理追加

# %%
import re
re.sub(r'からあげ','', '私はからあげです')
# Out:
# '私はです'

# %% [markdown]
# 再度テキストを読み込みます

# %%
text_list = []
with open('dogura_magura.txt', encoding='shift_jis') as f:
  text_list = f.readlines()

# %% [markdown]
# 不要な文字を削除する関数を定義します。

# %%
import re
def normalize_text(text):
  text = re.sub(r'それ', "", text)
  text = re.sub(r'よう', "", text)
  text = re.sub(r'もの', "", text)
  text = re.sub(r'これ', "", text)
  text = re.sub(r'うち', "", text)
  text = re.sub(r'ここ', "", text)
  text = re.sub(r'こと', "", text)
  text = re.sub(r'もの', "", text)
  text = re.sub(r'そう', "", text)
  text = re.sub(r'\n', "", text)
  text = text.strip()
  return text

# %%
new_text_list = []
for text in text_list:
  text = normalize_text(text)
  new_text_list.append(text)

# %%
from janome.tokenizer import Tokenizer

t = Tokenizer()
words = []
for text in new_text_list:
  tokens = t.tokenize(text)
  for token in tokens:
    pos = token.part_of_speech.split(',')[0]
    if pos == '名詞':
      words.append(token.surface)

text = ' '.join(words)

# %%
text[500:600]
# Out:
# 'ペンキ 塗 天井 裏 薄 塵埃 ほこり 蔽 裸 電球 タッタ 一つ ブラ 赤 硝子 球 ガラス だま 横腹 蠅 はえ 一 匹 凝然 真下 人造 石 床 上 私 大の字 型 なり 私 大の字 型 なり '

# %%
fpath = '/usr/share/fonts/opentype/ipafont-gothic/ipagp.ttf'
wordcloud = WordCloud(background_color="white", font_path=fpath, width=900, height=500).generate(text)
plt.figure(figsize=(15,12))
plt.imshow(wordcloud)
plt.axis("off")
plt.show()

# %% [markdown]
# ## Word2Vecで可視化

# %% [markdown]
# 最初に分かち書きした文章を、テキストファイルに保存します。

# %%
filename='wakachi_text.txt'
with open(filename, 'w', encoding='utf-8') as f:
  f.write(text)
print("file is saved")
# Out:
# file is saved

# %%
print(text[0:500])
# Out:
# ドグラ・マグラ 夢野 久作 ------------------------------------------------------- テキスト 中 記号 ルビ 例 蜜蜂 みつば ルビ 文字 列 始まり 特定 記号 例 大の字 型 なり ＃］： 入力 者 注 主 外字 説明 傍点 位置 指定 数字 JIS X 0213 面 区点 番号 Unicode 底本 ページ 行 数 例 ）※［＃ ローマ 数字 1 1 - 13 - 21 ＃…］： 点 例 五 月 於 ［＃ 二 二 倍 踊り字 縦 形 繰り返し 記号 例 やう 語り 出 づるやう 濁点 付き 二 倍 踊り字 ／″＼」 ------------------------------------------------------- ＃ ページ 左右 中央 ＃ ５ 字 下げ 巻頭 歌 胎児 胎児 母親 心 の ＃ 字 ＃ 改 ページ ブウウ ンンン ンンンン 私 ウスウス 眼 時 蜜蜂 みつば 音 弾力 余韻 私 耳 穴 中 ジッ 今 真夜中 直覚 どこ 近く ボンボン 時計 ん 蜜蜂 の 余韻 そこ ら 中 ヒッソリ 私 眼 白

# %%
# !cat wakachi_text.txt
# Out:
# ドグラ・マグラ 夢野 久作 ------------------------------------------------------- テキスト 中 記号 ルビ 例 蜜蜂 みつば ルビ 文字 列 始まり 特定 記号 例 大の字 型 なり ＃］： 入力 者 注 主 外字 説明 傍点 位置 指定 数字 JIS X 0213 面 区点 番号 Unicode 底本 ページ 行 数 例 ）※［＃ ローマ 数字 1 1 - 13 - 21 ＃…］： 点 例 五 月 於 ［＃ 二 二 倍 踊り字 縦 形 繰り返し 記号 例 やう 語り 出 づるやう 濁点 付き 二 倍 踊り字 ／″＼」 ------------------------------------------------------- ＃ ページ 左右 中央 ＃ ５ 字 下げ 巻頭 歌 胎児 胎児 母親 心 の ＃ 字 ＃ 改 ページ ブウウ ンンン ンンンン 私 ウスウス 眼 時 蜜蜂 みつば 音 弾力 余韻 私 耳 穴 中 ジッ 今 真夜中 直覚 どこ 近く ボンボン 時計 ん 蜜蜂 の 余韻 そこ ら 中 ヒッソリ 私 眼 白 ペンキ 塗 天井 裏 薄 塵埃 ほこり 蔽 裸 電球 タッタ 一つ ブラ 赤 硝子 球 ガラス だま 横腹 蠅 はえ 一 匹 凝然 真下 人造 石 床 上 私 大の字 型 なり 私 大の字 型 なり 凝然 まま 瞼 まぶた 一 パイ 眼 球 たま グルリグルリ 上下 左右 廻転 混凝土 コンクリート 壁 二 間 四方 部屋 三 方 壁 鉄格子 鉄 網 かな あみ 二 重 縦 磨 硝子 すりガラス 窓 一つ 宛 都合 三つ トテ 要心 じん 堅固 部屋 感じ 窓 側 壁 根 岩 乗 がん ょう 鉄 寝台 一 個 入口 方向 枕 上 真白 寝具 展 べた まま ところ 誰 私 頭 自分 身体 ゴワゴワ 木綿 着物 二 枚 ガーゼ 帯 一 本 胸高 そこ 肥 四 本 手足 全体 ドス 垢 だらけ キタナラシサ こ 右手 め 自分 顔 撫 鼻 ん 眼 窪 頭髪 たま 蓬 顎 鬚 あごひげ モジャモジャ 私 モウ 一 度 顔 そこ ら キョロキョロ 誰 俺 コンナ 人間 胸 動悸 早鐘 撞 くに 初め 呼吸 喘 ぎ ヒッソリ 不思議 自分 自分 どこ 何者 自分 過去 思い出 ブウ ンンン ボンボン 時計 音 タッタ 一つ 記憶 ソレッ 切り 気 慥 森閑 しんかん 暗黒 部屋 外 どこ どこ 夢 夢 私 窓 前 磨 硝子 平面 そこ 自分 容貌 かお かたち 何 記憶 喚 び 起 何 磨 硝子 表面 髪の毛 モジャモジャ 悪鬼 私 自身 影法師 私 身 飜 寝台 枕元 入口 扉 ドア 鍵 穴 真鍮 しん ゅう 金具 顔 金具 表面 私 顔 只 反射 寝台 脚 寝具 着物 帯 私 名前 愚 ろ 頭文字 発見 私 私 未知 世界 未知 私 私 自身 誰 私 私 帯 まま 無限 空間 ス ッ 垂直 どこ 気 臓腑 底 戦慄 せんりつ 我 大声 金属 性 突拍子 とっぴょうし 甲高 い 声 声 私 過去 何事 間 四方 コンクリート 壁 矢 張 や 無駄 声 烈 はげ 波動 あと 四つ 壁 三つ 窓 一つ 扉 厳粛 声 声 咽喉 のど 奥 方 たんび 静寂 さ 奥歯 ガチガチ 音 膝頭 ひざ しら 自然 ガクガク 自分 自身 何者 さ 私 喘 ぎ 出 恐怖 部屋 中央 まんなか 棒立ち まま 監獄 精神 病院 呼吸 音 凩 の 深夜 四壁 反響 の 私 気 眼 前 ズウ 真 棒 の 強直 ょく 全身 汗 ビッショリ まま 向 様 ざま スト ン 吾 知らず 観念 眼 機械 足 眼 寝台 向 側 混凝土 コンクリート 壁 凝視 混凝土 壁 向 側 奇妙 声 確か 女 声 音調 トテ 人間 肉声 嗄 しゃが 底 響 混凝土 壁 の 兄 さま 兄 さま 兄 さま 兄 さま 兄 さま 兄 さま 兄 さま モウ 一 度 今 声 エ ッ 私 愕然 がく ぜん モウ 一 度 背後 うし ろ 部屋 中 私 以外 人間 一 人 事 承知 女 声 滲 コンクリート 壁 一部分 穴 あく 凝視 兄 さま 兄 さま 兄 さま 兄 さま 兄 さま 部屋 兄 様 あたし 妾 あたし 兄 様 許嫁 いいなずけ 貴方 あなた 未来 妻 妾 あたし あたし 今 声 モウ 一 度 頂戴 エ ッ 兄 様 兄 様 兄 様 兄 様 ッ 私 眼瞼 まぶた 眼 唇 アングリ 声 ヒョロヒョロ 二 三 歩 前 両手 下腹 シッカリ 混凝土 コンクリート 壁 白眼 ら 者 心臓 虚空 程 モノスゴイ 純情 叫び 臓腑 ドン底 措 タマラナイ 絶体絶命 声 私 初め 先 何 千 年 何 万 年 真剣 怨 みの 声 深夜 混凝土 壁 向う 私 の 兄 さま 兄 さま 兄 さま 兄 さま 返事 の あたし あたし あたし あたし 兄 さま 忘れ の 妾 あたし あたし 兄 様 許嫁 いいなずけ 妾 妾 忘れ の 妾 兄 様 一緒 前 晩 結婚式 前 晩 真夜中 兄 様 手 の チャント 墓 中 の 幽霊 何 兄 さま 兄 さま 兄 さま 兄 さま ナゼ 返事 の 兄 様 時 事 忘れ の 私 ヨロヨロ 背後 うし ろ 蹌踉 ろ め モウ 一 度 眼 皿 の 声 方向 凝視 何 奇怪 言葉 壁 向う 少女 私 私 許嫁 私 結婚式 前 晩 私 手 女 自分 自身 私 壁 一 重 ひと 向う 部屋 閉 籠 こ め まま 夜 昼 私 想像 怪奇 事実 私 過去 記憶 死物 狂 ぐる 努力 キチガイ 本気 キチガイ キチガイ 馬鹿 不思議 事 アハハハ 私 笑い 私 顔面 筋肉 まま 悲痛 深刻 声 混凝土 壁 の 私 私 確信 真剣 悽愴 兄 さま 兄 さま 兄 さま 御返事 の 妾 タッタ 一言 タッタ 一言 御返事 タッタ 一言 タッタ 一言 御返事 の 病院 医者 様 妾 キチガイ 事 の 兄 様 妾 声 事 院長 さん 一緒 退院 兄 様 兄 様 兄 様 兄 さま 御返事 の 妾 苦しみ の 毎日 毎日 毎夜 毎夜 お呼び 声 兄 様 耳 ら の 兄 様 兄 様 兄 様 兄 様 あたし 声 壁 向 側 モウ 一つ 別 物音 平手 コブシ 生身 まみ 手 コンクリート 壁 音 皮膚 肉 意気 組 女 手 音 私 壁 向う 血 痕跡 あと 想像 眼 瞠 奥歯 兄 様 兄 様 兄 様 兄 様 兄 様 手 あたし 妾 兄 様 ほか 便 たよ 方 一 人 可哀想 妹 一 人 ポッチ 兄 様 妾 忘れ の 兄 様 おんなじ 世界中 タッタ 二 人 妾 たち の 他人 ひと キチガイ 病院 離れ離れ 籠 め の 兄 様 返事 妾 事 ホント 事 の 妾 妾 兄 様 精神病 患者 事 の タッタ 一言 タッタ 一 コト 御返事 モヨコ 妾 名前 兄 様 兄 様 兄 様 兄 様 兄 様 妾 声 眼 眼 私 寝台 上 声 あたり 混凝土 コンクリート 壁 す 返事 少女 苦しみ 私 自身 どこ 何者 事実 一刻 タマラナイ 衝動 の グット 唾液 つば 嚥 思い 止 とど ソロ ソロ 寝台 上 すべ 壁 一 点 凝視 まま 声 正反対 位置 窓 処 後退 あと ざ 私 返事 の 否 返事 の 私 彼女 私 妻 の 人間 あれ 深刻 彼女 純情 叫び声 顔 私 自分 過去 真実 記憶 タッタ 今 ブウウン ンンン 時計 音 一つ 不可思議 痴呆 患者 私 私 彼女 夫 返事 事 出来 返事 お蔭 私 自由 事 時 私 ホン トウ 氏素性 うじ すじ ょう 間違い 本名 彼女 正気 の 精神病 患者 の 判断 根拠 私 彼女 正真正銘 精神病 患者 彼女 モノスゴイ 相手 彼女 深刻 幻覚 外 ほか 私 ウッカリ 返事 大変 間違い 原因 もと 彼女 人間 この世 現在 人間 私 以外 人間 私 自分 軽率 はずみ 他人 妻 横 事 他人 恋人 冒涜 ぼうとく 事 不安 恐怖 次 唾液 つば 嚥 両手 シッカリ 彼女 叫び声 切り 壁 私 真正面 の 兄 様 兄 様 兄 様 兄 様 兄 様 幽霊 限り 純情 怨み 叫び 私 頭髪 両手 引掴 ん 十 本 爪 つめ 血 兄 さま 兄 さま 兄 さま 妾 貴方 あなた の 貴方 の 兄 様 手 私 掌 の 顔 コスリ 貴女 あなた 思い違い の 僕 貴女 の モウ ところ 口 噤 ん 事実 断言 今 私 自分 過去 彼女 言葉 否定 材料 一つ 兄弟 生れ 故郷 事 自分 豚 人間 今 今 私 私 拳骨 げんこつ 耳 後部 うし ろ 骨 コツンコツン そこ 何 記憶 彼女 声 息 切れ切れ 事 悲痛 深刻 高潮 兄 さま あたし 私 声 今 一 度 四方 壁 窓 扉 ドア 立 何 処 全身 ゾーッ 粟 立 あわ 入口 扉 ドア 走り 鉄 ほど 岩 乗 がん ょう 青 塗 板 平面 全力 衝突 ぶつ 鍵 穴 引続 物音 絶え絶え 叫び声 痺 び 脅 窓 格子 両手 力 一 パイ 下 方 片隅 引歪 ひき ゆ め 事 以上 人間 力 私 部屋 真中 ガタガタ 慄 モウ 一 度 部屋 隅々 私 イッタイ 人間 世界 の 私 ツイ 今しがた 世界 何 責苦 の 部屋 正気 回復 自己 忘却 無間 むげん 地獄 何 反響 聞 時計 音 どこ 何者 女性 叫び 苛責 さい 初め 絶体絶命 活 いき 地獄 この世 事 深刻 悲恋 事 永劫 えい 苛責 私 踵 かかと 地団駄 じだんだ ベタリ 仰向け 起 上 部屋 中 位 隣室  ...

# %% [markdown]
# ライブラリをインストールします。

# %%
#!pip install gensim

# %%
from gensim.models import word2vec
import logging
logging.basicConfig(
    format='%(asctime)s : %(levelname)s : %(message)s',
    level=logging.INFO
    )
sentences = word2vec.LineSentence('wakachi_text.txt')
model = word2vec.Word2Vec(
    sentences,
    sg=1,
    size=300,
    window=5,
    min_count=5,
)

model.save("./word2vec.model")
# Out:
# 2021-06-01 13:50:41,570 : INFO : collecting all words and their counts
# 2021-06-01 13:50:41,584 : INFO : PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# 2021-06-01 13:50:41,603 : INFO : collected 11963 word types from a corpus of 89539 raw words and 9 sentences
# 2021-06-01 13:50:41,604 : INFO : Loading a fresh vocabulary
# 2021-06-01 13:50:41,616 : INFO : effective_min_count=5 retains 2943 unique words (24% of original 11963, drops 9020)
# 2021-06-01 13:50:41,617 : INFO : effective_min_count=5 leaves 74320 word corpus (83% of original 89539, drops 15219)
# 2021-06-01 13:50:41,628 : INFO : deleting the raw counts dictionary of 11963 items
# 2021-06-01 13:50:41,629 : INFO : sample=0.001 downsamples 52 most-common words
# 2021-06-01 13:50:41,630 : INFO : downsampling leaves estimated 65821 word corpus (88.6% of prior 74320)
# 2021-06-01 13:50:41,638 : INFO : estimated required memory for 2943 words and 300 dimensions: 8534700 bytes
# 2021-06-01 13:50:41,639 : INFO : resetting layer weights
# 2021-06-01 13:50:42,176 : INFO : training model with 3 workers on 2943 vocabulary and 300 features, using sg=1 hs=0 sample=0.001 negative=5 window=5
# 2021-06-01 13:50:42,593 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-06-01 13:50:42,676 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-06-01 13:50:42,696 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-06-01 13:50:42,698 : INFO : EPOCH - 1 : training on 89539 raw words (65823 effective words) took 0.5s, 127402 effective words/s
# 2021-06-01 13:50:43,203 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-06-01 13:50:43,218 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-06-01 13:50:43,223 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-06-01 13:50:43,224 : INFO : EPOCH - 2 : training on 89539 raw words (65809 effective words) took 0.5s, 126937 effective words/s
# 2021-06-01 13:50:43,657 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-06-01 13:50:43,704 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-06-01 13:50:43,720 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-06-01 13:50:43,720 : INFO : EPOCH - 3 : training on 89539 raw words (65827 effective words) took 0.5s, 133949 effective words/s
# 2021-06-01 13:50:44,126 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-06-01 13:50:44,198 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-06-01 13:50:44,205 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-06-01 13:50:44,206 : INFO : EPOCH - 4 : training on 89539 raw words (65741 effective words) took 0.5s, 137002 effective words/s
# 2021-06-01 13:50:44,624 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-06-01 13:50:44,673 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-06-01 13:50:44,682 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-06-01 13:50:44,683 : INFO : EPOCH - 5 : training on 89539 raw words (65785 effective words) took 0.5s, 139642 effective words/s
# 2021-06-01 13:50:44,685 : INFO : training on a 447695 raw words (328985 effective words) took 2.5s, 131188 effective words/s
# 2021-06-01 13:50:44,686 : INFO : saving Word2Vec object under ./word2vec.model, separately None
# 2021-06-01 13:50:44,688 : INFO : not storing attribute vectors_norm
# 2021-06-01 13:50:44,690 : INFO : not storing attribute cum_table
# 2021-06-01 13:50:44,762 : INFO : saved ./word2vec.model

# %%
with open('vector.tsv', 'w', encoding='utf-8') as f, \
    open('metadata.tsv', 'w', encoding='utf-8') as g:

  for word in model.wv.vocab.keys():
    embedding = model.wv[word]

    # Save vector TSV file
    f.write('\t'.join([('%f' % x) for x in embedding]) + '\n')

    # Save metadata TSV file
    g.write(word + '\n')

# %% [markdown]
# ファイルのダウンロード

# %%
from google.colab import files
files.download('vector.tsv')
files.download('metadata.tsv')

# %% [markdown]
# [Embedding projector](http://projector.tensorflow.org/)のサイトに行き、ダウンロードしたファイルを可視化する
